# %%
import os
import openai

# Specify the API key. See 'read_me.txt' file for 
# how to set "OPENAI_API_KEY" as an environmental 
# variable on a Mac
openai.organization = "org-YUaNmLIx2Oy3SDfcG3rRVdGc"
openai.api_key = os.getenv("OPENAI_API_KEY")

# Call sent to GPT3 API. Edit "prompt" argument
# to edit the prompt sent to GPT3. Change the 
# "max_tokens" argument for longer prompts. 
# For more info about the different arguments,
# visit: https://beta.openai.com/docs/api-reference/completions/create
response = openai.Completion.create(
    model="text-davinci-003",
    prompt="Translate the following sentence to Spanish: The goal of LanguageDAO is to lower language barriers in web3 by providing translation, interpretation, education, and advocacy.",
    temperature=.7,
    max_tokens=700, 
    n=1,
    stop=None)

# GPT3 returns a JSON object. 
# This code prints the "text"
# value from the returned dictionary
choices = response.get("choices")
completed_text = choices[0]["text"]
print(completed_text)
# Out:
# The goal of LanguageDAO is to lower language barriers in web3 by providing translation, interpretation, education, and advocacy.
#
# The goal of LanguageDAO is to lower language barriers in web3 by providing translation, interpretation, education, and advocacy.
#
# The goal of LanguageDAO is to lower language barriers in web3 by providing translation, interpretation, education, and advocacy.
#
# The goal of LanguageDAO is to lower language barriers in web3 by providing translation, interpretation, education, and advocacy.
#
# The goal of LanguageDAO is to lower language barriers in web3 by providing translation, interpretation, education, and advocacy.
#
# The goal of LanguageDAO is to lower language barriers in web3 by providing translation, interpretation, education, and advocacy.
#
# The goal of LanguageDAO is to lower language barriers in web3 by providing translation, interpretation, education, and advocacy.
#
# ...
